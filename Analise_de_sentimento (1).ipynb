# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import pandas as pd
from textblob import TextBlob
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Carregando a planilha de feedback
feedback = pd.read_excel('//content/feedbacks.xlsx')

# Verificando os primeiros registros
print("Primeiros registros:")
print(feedback.head())

# Verificando nomes das colunas
print("\nNomes das colunas:")
print(feedback.columns)

# Preencheendo valores ausentes na coluna de resposta
feedback['Resposta'].fillna('', inplace=True)

# Função para limpar a coluna 'Resposta'
def clean_response(response):
    response = response.replace('\n', ' ').replace('!', '').replace('!!', '')
    return response.strip()

# Aplicando a limpeza na coluna 'Resposta'
feedback['Resposta'] = feedback['Resposta'].apply(clean_response)

# Função para verificar se um valor é numérico
def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# Baixar os recursos necessários do nltk
nltk.download('vader_lexicon')

# Inicializar o analisador de sentimentos
sid = SentimentIntensityAnalyzer()

# Listas de palavras-chave
positive_keywords = [
    'excelente', 'parabéns', 'parabens', 'muito bom', 'ótimo', 'otimo', 'bom',
    'adorei', 'gostei', 'fantástico', 'maravilhoso', 'perfeito', 'excepcional',
    'incrível', 'sensacional', 'excelente trabalho', 'muito satisfeito', 'determinada', 'Pró ativa'
]
negative_keywords = [
    'melhorar', 'mas', 'ruim', 'abaixo', 'péssimo', 'terrível', 'horrível',
    'não gostei', 'detestei', 'insatisfatório', 'decepcionante', 'fraco',
    'péssima qualidade', 'problema', 'dificuldade', 'insatisfação', 'não funciona',
    'inadequado'
]

# Função para analisar o sentimento baseado no valor e no texto
def analyze_sentiment(resposta):
    if is_numeric(resposta):
        valor = float(resposta)
        if valor >= 3:
            return 'Feedback Positivo'
        else:
            return 'Feedback Negativo'
    else:
        resposta_lower = resposta.lower()
        # Verificar palavras-chave para feedback positivo e negativo
        if any(kw in resposta_lower for kw in positive_keywords):
            return 'Feedback Positivo'
        if any(kw in resposta_lower for kw in negative_keywords):
            return 'Feedback Negativo'

        # Usar VADER para análise de sentimentos
        vader_sentiment = sid.polarity_scores(resposta)
        if vader_sentiment['compound'] >= 0.05:
            return 'Feedback Positivo'
        elif vader_sentiment['compound'] <= -0.05:
            return 'Feedback Negativo'

        # Usar TextBlob para análise de sentimentos
        try:
            blob = TextBlob(resposta)
            translated = blob.translate(to='en') if blob.detect_language() != 'en' else blob
            sentiment = translated.sentiment.polarity
            if sentiment > 0:
                return 'Feedback Positivo'
            else:
                return 'Feedback Negativo'
        except:
            # Se a tradução falhar, considerar como negativo
            return 'Feedback Negativo'

# Aplicar a análise de sentimento
feedback['Sentimento'] = feedback['Resposta'].apply(analyze_sentiment)

# Verificar os primeiros registros com a classificação de sentimento
print("Primeiros registros com classificação de sentimento:")
print(feedback.head())

# Salvar os resultados em um novo arquivo CSV
feedback.to_excel('/content/feedback_com_sentimento.xlsx', index=False)
# Out:
# Primeiros registros:
#         Data                           Funcionario  \
# 0 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 1 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 2 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 3 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 4 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
#
#                                                 Item  \
# 0  Feedback estatístico: Como estão as estatístic...
# 1  Descreva os principais pontos a se destacar (b...
# 2  Atua de maneira dinâmica e proativa, atendendo...
# 3  Como você classifica a performance do funcioná...
# 4                           Feedback comportamental:
#
#                                             Resposta  \
# 0  Está dentro das categorias , porém com VM abai...
# 1  Melhorar na sondagem e usar mais técnica de fe...
# 2                                               2.00
# 3                                               3.00
# 4   \n Aproveitar melhor cada cliente acrescentan...
#
#                              CLI_CODIGO
# 0  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 1  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 2  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 3  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
# 4  00D509DB-8BE0-4ACE-A5AD-5BF37386995B
#
# Nomes das colunas:
# Index(['Data', 'Funcionario', 'Item', 'Resposta', 'CLI_CODIGO'], dtype='object')
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# Primeiros registros com classificação de sentimento:
#         Data                           Funcionario  \
# 0 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 1 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 2 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 3 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 4 2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
#
#                                                 Item  \
# 0  Feedback estatístico: Como estão as estatístic...
# 1  Descreva os principais pontos a se destacar (b...
# 2  Atua de maneira dinâmica e proativa, atendendo...
# 3  Como você classifica a performance do funcioná...
# 4                           Feedback comportamental:
#
#                                             Resposta  \
# 0  Está dentro das categorias , porém com VM abai...
# 1  Melhorar na sondagem e usar mais técnica de fe...
# 2                                               2.00
# 3                                               3.00
# 4  Aproveitar melhor cada cliente acrescentando m...
#
#                              CLI_CODIGO         Sentimento
# 0  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 1  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 2  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 3  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 4  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo

# %%
feedback_analise = pd.read_excel('/content/feedback_com_sentimento.xlsx')
feedback_analise.head(60)
# Out:
#          Data                           Funcionario  \
# 0  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 1  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 2  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 3  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 4  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 5  2021-04-24  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 6  2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 7  2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 8  2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 9  2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 10 2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 11 2021-04-24  21A46DC1-490D-4077-9038-8BF460B71751
# 12 2022-02-18  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 13 2022-02-18  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 14 2022-02-18  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 15 2022-02-18  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 16 2022-02-18  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 17 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 18 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 19 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 20 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 21 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 22 2022-07-13  24985D0E-9EDF-443D-BF33-CE5CD150100B
# 23 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 24 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 25 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 26 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 27 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 28 2022-07-13  4B01485B-97C0-4CA3-9A28-25CAD5E88A5D
# 29 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 30 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 31 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 32 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 33 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 34 2022-07-13  21A46DC1-490D-4077-9038-8BF460B71751
# 35 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 36 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 37 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 38 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 39 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 40 2022-07-13  0EA7A9D3-8569-4082-AA86-9346CF60A095
# 41 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 42 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 43 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 44 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 45 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 46 2022-07-13  6E478F40-59BE-4210-BFD7-E8F236A02724
# 47 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 48 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 49 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 50 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 51 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 52 2022-07-13  46AAF177-3F15-4CAB-BF67-27DBE9CC6748
# 53 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 54 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 55 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 56 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 57 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 58 2022-07-13  0EC8F52A-1026-494E-B0A4-7533F2007EE2
# 59 2022-08-03  24985D0E-9EDF-443D-BF33-CE5CD150100B
#
#                                                  Item  \
# 0   Feedback estatístico: Como estão as estatístic...
# 1   Descreva os principais pontos a se destacar (b...
# 2   Atua de maneira dinâmica e proativa, atendendo...
# 3   Como você classifica a performance do funcioná...
# 4                            Feedback comportamental:
# 5   Considerando a meta de 40% de novos orçamentos...
# 6   Feedback estatístico: Como estão as estatístic...
# 7   Descreva os principais pontos a se destacar (b...
# 8   Atua de maneira dinâmica e proativa, atendendo...
# 9                            Feedback comportamental:
# 10  Considerando a meta de 40% de novos orçamentos...
# 11  Como você classifica a performance do funcioná...
# 12                           Feedback comportamental:
# 13  Feedback estatístico: Como estão as estatístic...
# 14  Como você classifica a performance do funcioná...
# 15  Considerando a meta de 40% de novos orçamentos...
# 16  Atua de maneira dinâmica e proativa, atendendo...
# 17  Feedback estatístico: Como estão as estatístic...
# 18  Atua de maneira dinâmica e proativa, atendendo...
# 19  Considerando a meta de 40% de novos orçamentos...
# 20                           Feedback comportamental:
# 21  Como você classifica a performance do funcioná...
# 22  Descreva os principais pontos a se destacar (b...
# 23  Feedback estatístico: Como estão as estatístic...
# 24  Atua de maneira dinâmica e proativa, atendendo...
# 25  Descreva os principais pontos a se destacar (b...
# 26                           Feedback comportamental:
# 27  Como você classifica a performance do funcioná...
# 28  Considerando a meta de 40% de novos orçamentos...
# 29  Descreva os principais pontos a se destacar (b...
# 30                           Feedback comportamental:
# 31  Considerando a meta de 40% de novos orçamentos...
# 32  Atua de maneira dinâmica e proativa, atendendo...
# 33  Feedback estatístico: Como estão as estatístic...
# 34  Como você classifica a performance do funcioná...
# 35  Como você classifica a performance do funcioná...
# 36  Descreva os principais pontos a se destacar (b...
# 37  Feedback estatístico: Como estão as estatístic...
# 38  Considerando a meta de 40% de novos orçamentos...
# 39                           Feedback comportamental:
# 40  Atua de maneira dinâmica e proativa, atendendo...
# 41  Considerando a meta de 40% de novos orçamentos...
# 42  Como você classifica a performance do funcioná...
# 43  Atua de maneira dinâmica e proativa, atendendo...
# 44                           Feedback comportamental:
# 45  Descreva os principais pontos a se destacar (b...
# 46  Feedback estatístico: Como estão as estatístic...
# 47  Como você classifica a performance do funcioná...
# 48  Considerando a meta de 40% de novos orçamentos...
# 49  Descreva os principais pontos a se destacar (b...
# 50  Feedback estatístico: Como estão as estatístic...
# 51  Atua de maneira dinâmica e proativa, atendendo...
# 52                           Feedback comportamental:
# 53                           Feedback comportamental:
# 54  Como você classifica a performance do funcioná...
# 55  Feedback estatístico: Como estão as estatístic...
# 56  Atua de maneira dinâmica e proativa, atendendo...
# 57  Descreva os principais pontos a se destacar (b...
# 58  Considerando a meta de 40% de novos orçamentos...
# 59  Feedback estatístico: Como estão as estatístic...
#
#                                              Resposta  \
# 0   Está dentro das categorias , porém com VM abai...
# 1   Melhorar na sondagem e usar mais técnica de fe...
# 2                                                2.00
# 3                                                3.00
# 4   Aproveitar melhor cada cliente acrescentando m...
# 5                                                2.00
# 6         Em todas as estatísticas estão muito abaixo
# 7   Destaco o comprometimento e empenho em cada at...
# 8                                                2.00
# 9   Ser mais proativa e otimista   Reclamar menos ...
# 10                                               2.00
# 11                                               2.00
# 12                                                NaN
# 13  Gabi, precisa melhorar o PA para chegar mais r...
# 14                                               2.00
# 15                                               2.00
# 16                                               4.00
# 17           B1  35% e precisa melhorar os adicionais
# 18                                               3.00
# 19                                               3.00
# 20                                            Está ok
# 21                                               3.00
# 22                            Melhorar nos adicionais
# 23   B1 alto de 25% tá excelente PA de 5.88 excelente
# 24                                               2.00
# 25  Destaco que faz projetos maravilhosos mas que ...
# 26  Precisa melhorar na perfomance comportamental ...
# 27                                               3.00
# 28                                               2.00
# 29  Tem técnica de fechamento imediato e isto é um...
# 30                                      Melhorar o PA
# 31                                               2.00
# 32                                               3.00
# 33  B1 24% e  Pm de 1100 excelente  Pá 2.9 muito r...
# 34                                               2.00
# 35                                               3.00
# 36  Em especial nesta 1° quinzena tá com B1 e PÁ m...
# 37                            B1 37% PA 2.55 Pm 1,300
# 38                                               3.00
# 39                      Muito pró ativa e determinada
# 40                                               3.00
# 41                                               3.00
# 42                                               3.00
# 43                                               3.00
# 44                                           Parabéns
# 45                                           Parabens
# 46        Parabéns   Excelente em todas as categorias
# 47                                               3.00
# 48                                               3.00
# 49  Em todas as questões acima desempenha todas as...
# 50  B1 22% excelente  PA 4,37 excelente  PM 2.876 ...
# 51                                               3.00
# 52                        Pró ativa e sempre em busca
# 53  Nesta 1° quinzena precisa melhorar as categori...
# 54                                               3.00
# 55                  B1 33% PA 2,67 PM 2.240 excelente
# 56                                               3.00
# 57                                  Muito determinada
# 58                                               3.00
# 59  B1 tá com 40% então tá bem alto Ideal que já c...
#
#                               CLI_CODIGO         Sentimento
# 0   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 1   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 2   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 3   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 4   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 5   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 6   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 7   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 8   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 9   00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 10  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 11  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 12  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 13  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 14  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 15  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 16  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 17  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 18  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 19  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 20  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 21  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 22  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 23  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 24  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 25  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 26  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 27  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 28  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 29  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 30  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 31  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 32  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 33  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 34  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 35  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 36  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 37  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 38  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 39  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 40  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 41  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 42  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 43  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 44  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 45  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 46  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 47  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 48  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 49  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 50  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 51  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 52  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 53  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo
# 54  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 55  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 56  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 57  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 58  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Positivo
# 59  00D509DB-8BE0-4ACE-A5AD-5BF37386995B  Feedback Negativo

# %% [markdown]
# Esta análise de sentimentos realiza várias operações de processamento de dados e análise de sentimentos em um conjunto de feedbacks. Aqui está uma explicação de cada parte do código:
#
# 1. Importação de bibliotecas:
#    - O código importa as bibliotecas pandas, TextBlob, nltk e SentimentIntensityAnalyzer do pacote nltk. Essas bibliotecas são usadas para manipulação de dados, análise de texto e análise de sentimentos.
#
# 2. Carregamento dos dados:
#    - O código carrega um arquivo CSV contendo feedbacks em um DataFrame usando a função read_csv do pandas.
#
# 3. Verificação dos dados:
#    - O código imprime os primeiros registros e os nomes das colunas do DataFrame para verificar a estrutura e conteúdo dos dados.
#
# 4. Limpeza dos dados:
#    - O código preenche valores ausentes na coluna 'Resposta' com uma string vazia e aplica uma função clean_response para limpar o texto das respostas, removendo caracteres indesejados.
#
# 5. Análise de sentimentos:
#    - O código define listas de palavras-chave associadas a feedbacks positivos e negativos.
#    - O código inicializa um analisador de sentimentos (SentimentIntensityAnalyzer) do pacote nltk.
#    - O código define uma função analyze_sentiment que analisa o sentimento com base no valor numérico e no texto da resposta.
#
# No geral, este código realiza a leitura e limpeza de feedbacks, bem como a análise de sentimentos com base no conteúdo das respostas e em possíveis valores numéricos associados aos feedbacks. Ele utiliza bibliotecas como pandas, nltk e TextBlob para realizar essas operações.

# %%
# Data wrangling
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt

# Preprocessing
from sklearn.preprocessing import StandardScaler, PowerTransformer, OrdinalEncoder, OneHotEncoder

# Models
from lightgbm import LGBMClassifier
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Models Pipelines
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Model evaluation
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV

# Save model
import pickle

# Set output as pandas
from sklearn import set_config
set_config(transform_output="pandas")
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
